# %%
while current is not None:
    if current.value = x:
        return True
    current = current.next
return False

# %%
def traverse(self):
    cur = self.head.next
    while cur:
        print(cur.value)
    cur = cur.next

def reverse(self):
    cur = self.head
    pre = None

    while cur:
            temp = cur.next
            cur.next = pre
            pre = cur
            cur = temp

    return pre
# Out:
#   Cell In[1], line 2
#
#     ^
# SyntaxError: incomplete input
